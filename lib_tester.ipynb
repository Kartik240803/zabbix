# %%
import zabbix_db as zb
import time
import pandas as pd

# %%
db_config = {
    'db_type': 'mysql',  # or 'postgresql'
    'host': '140.238.230.93',
    'port': 3306,  # 5432 for PostgreSQL
    'database': 'zabbix',
    'user': 'kartik',
    'password': 'Kartik@24082003'
}

# %% [markdown]
# ##  Setting Test variables

# %%
hostname = 'Zabbix server'
metric_name = 'CPU utilization'
time_to = int(time.time())
time_from = time_to - 86400
itemid = 42269

# %% [markdown]
# ## Testing Get Item Details Function

# %% [markdown]
# ### With HostName

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_item_detail(
        hostname=hostname,
        item_name=metric_name
    )
    print(result)
# Out:
# {'hostname': 'Zabbix server', 'itemid': 42269, 'hostid': 10084, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}

# %% [markdown]
# ### Without HostName

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_item_detail(
        item_name=metric_name
    )
    print(result)
# Out:
# [{'hostname': 'Zabbix server', 'itemid': 42269, 'hostid': 10084, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'Firewall1 SNMP', 'itemid': 49614, 'hostid': 10713, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'Firewall2 SNMP', 'itemid': 49919, 'hostid': 10715, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'vector-test', 'itemid': 50471, 'hostid': 10721, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'test12', 'itemid': 50857, 'hostid': 10726, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'asg-ip-13.232.218.1', 'itemid': 53831, 'hostid': 10792, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'asg-ip-13.203.155.142', 'itemid': 53939, 'hostid': 10793, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'nirmitalma', 'itemid': 57732, 'hostid': 10799, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'nirmitcentos', 'itemid': 57808, 'hostid': 10800, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'asg-ip-140.245.29.55', 'itemid': 57960, 'hostid': 10802, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'ip-172-31-94-226.ec2.internal', 'itemid': 58036, 'hostid': 10803, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'alma', 'itemid': 58146, 'hostid': 10804, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'test-zab-kartik', 'itemid': 59036, 'hostid': 10808, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'asg-ip-122.170.27.131', 'itemid': 59112, 'hostid': 10809, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'asg', 'itemid': 59190, 'hostid': 10810, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'asg-ip-103.241.45.149', 'itemid': 59265, 'hostid': 10811, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_table_name': 'history', 'trends_table_name': 'trends'}, {'hostname': 'ip-172-31-54-55.ec2.internal', 'itemid': 59342, 'hostid': 10812, 'name': 'CPU utilization', 'history': '31d', 'trends': '365d', 'value_type': 0, 'status': 0, 'units': '%', 'history_tab ...

# %% [markdown]
# ## Get Data

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_history_data(
        itemid=itemid,
        time_from=time_from,
        time_to=time_to,
        history_table_name='history'
    )
    print(result)
# Out:
# [{'clock': 1749733284, 'value': 98.61082}, {'clock': 1749733224, 'value': 98.538797}, {'clock': 1749733164, 'value': 98.442943}, {'clock': 1749733104, 'value': 94.625551}, {'clock': 1749733044, 'value': 34.381296000000006}, {'clock': 1749732984, 'value': 65.04236399999999}, {'clock': 1749732924, 'value': 87.424772}, {'clock': 1749732864, 'value': 87.305394}, {'clock': 1749732804, 'value': 75.254266}, {'clock': 1749732744, 'value': 95.366017}, {'clock': 1749732684, 'value': 98.223958}, {'clock': 1749732624, 'value': 98.334452}, {'clock': 1749732564, 'value': 98.462831}, {'clock': 1749732504, 'value': 94.542482}, {'clock': 1749732444, 'value': 35.16354200000001}, {'clock': 1749732384, 'value': 66.160192}, {'clock': 1749732324, 'value': 87.156698}, {'clock': 1749732264, 'value': 87.350435}, {'clock': 1749732204, 'value': 69.42739399999999}, {'clock': 1749732144, 'value': 94.404772}, {'clock': 1749732084, 'value': 98.611169}, {'clock': 1749732024, 'value': 98.409434}, {'clock': 1749731964, 'value': 98.20778}, {'clock': 1749731904, 'value': 94.304541}, {'clock': 1749731844, 'value': 35.57284}, {'clock': 1749731784, 'value': 58.655384}, {'clock': 1749731724, 'value': 87.279226}, {'clock': 1749731664, 'value': 88.339282}, {'clock': 1749731604, 'value': 73.83689100000001}, {'clock': 1749731544, 'value': 94.437919}, {'clock': 1749731484, 'value': 98.204171}, {'clock': 1749731424, 'value': 98.24245}, {'clock': 1749731364, 'value': 98.366355}, {'clock': 1749731304, 'value': 94.813261}, {'clock': 1749731244, 'value': 35.192898}, {'clock': 1749731184, 'value': 57.545424}, {'clock': 1749731124, 'value': 87.423841}, {'clock': 1749731064, 'value': 87.828423}, {'clock': 1749731004, 'value': 67.643843}, {'clock': 1749730944, 'value': 94.999371}, {'clock': 1749730884, 'value': 98.137193}, {'clock': 1749730824, 'value': 98.223191}, {'clock': 1749730764, 'value': 98.231127}, {'clock': 1749730704, 'value': 94.427206}, {'clock': 1749730644, 'value': 34.421476999999996}, {'clock': 1749730584, 'value': 63.284963}, {'clock': 1749730524, 'value': 87.589248}, {'clock': 1749730464, 'value': 87.333417}, {'clock': 1749730404, 'value': 68.272181}, {'clock': 1749730344, 'value': 93.985215}, {'clock': 1749730284, 'value': 97.46777}, {'clock': 1749730224, 'value': 98.362578}, {'clock': 1749730164, 'value': 97.914131}, {'clock': 1749730104, 'value': 94.651533}, {'clock': 1749730044, 'value': 35.642815}, {'clock': 1749729984, 'value': 55.166183}, {'clock': 1749729924, 'value': 87.26013}, {'clock': 1749729864, 'value': 88.783238}, {'clock': 1749729804, 'value': 65.619216}, {'clock': 1749729744, 'value': 93.526542}, {'clock': 1749729684, 'value': 97.232604}, {'clock': 1749729624, 'value': 98.222371}, {'clock': 1749729564, 'value': 98.061267}, {'clock': 1749729504, 'value': 94.63807}, {'clock': 1749729444, 'value': 33.528052}, {'clock': 1749729384, 'value': 61.458027}, {'clock': 1749729324, 'value': 87.888721}, {'clock': 1749729264, 'value': 88.281842}, {'clock': 1749729204, 'value': 83.321415}, {'clock': 1749729144, 'value': 95.567227}, {'clock': 1749729084, 'value': 98.25311}, {'clock': 1749729024, 'value': 98.031314}, {'clock': 1749728964, 'value': 98.572868}, {'clock': 1749728904, 'value': 94.263878}, {'clock': 1749728844, 'value': 34.500147}, {'clock': 1749728784, 'value': 82.088613}, {'clock': 1749728724, 'value': 87.047635}, {'clock': 1749728664, 'value': 88.012459}, {'clock': 1749728604, 'value': 68.943028}, {'clock': 1749728544, 'value': 94.014366}, {'clock': 1749728484, 'value': 97.88697}, {'clock': 1749728424, 'value': 98.265508}, {'clock': 1749728364, 'value': 97.935722}, {'clock': 1749728304, 'value': 93.88422800000001}, {'clock': 1749728244, 'value': 34.770934999999994}, {'clock': 1749728184, 'value': 61.123728}, {'clock': 1749728124, 'value': 86.663858}, {'clock': 1749728064, 'value': 88.19106}, {'clock': 1749728004, 'value': 68.562182}, {'clock': 1749727944, 'value': 94.493143}, {'clock': 1749727884, 'value': 98.152647}, {'clock': 1749727824, 'value' ...

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_trend_data(
        itemid=itemid,
        time_from=time_from,
        time_to=time_to,
        trend_table_name='trends',
        statistical_measure='all'

    )
    print(result)
# Out:
# [{'clock': 1749729600, 'num': 60, 'value_avg': 82.47896985000003, 'value_min': 34.381296000000006, 'value_max': 98.611169}, {'clock': 1749726000, 'num': 60, 'value_avg': 83.4727927, 'value_min': 33.246545999999995, 'value_max': 98.572868}, {'clock': 1749722400, 'num': 60, 'value_avg': 79.51105921666667, 'value_min': 10.558797999999996, 'value_max': 99.535779}, {'clock': 1749718800, 'num': 60, 'value_avg': 81.4822858, 'value_min': 33.01150199999999, 'value_max': 98.244514}, {'clock': 1749715200, 'num': 60, 'value_avg': 82.07882308333332, 'value_min': 32.606778000000006, 'value_max': 98.261308}, {'clock': 1749711600, 'num': 60, 'value_avg': 82.72840198333336, 'value_min': 32.303889, 'value_max': 98.270071}, {'clock': 1749708000, 'num': 60, 'value_avg': 82.94792941666665, 'value_min': 32.274688999999995, 'value_max': 98.139515}, {'clock': 1749704400, 'num': 60, 'value_avg': 82.86920708333335, 'value_min': 31.316142999999997, 'value_max': 98.333543}, {'clock': 1749700800, 'num': 60, 'value_avg': 82.82604278333334, 'value_min': 32.041647, 'value_max': 98.177466}, {'clock': 1749697200, 'num': 60, 'value_avg': 82.95128171666666, 'value_min': 31.847347, 'value_max': 98.344538}, {'clock': 1749693600, 'num': 60, 'value_avg': 82.96375706666666, 'value_min': 31.839186999999995, 'value_max': 98.362377}, {'clock': 1749690000, 'num': 60, 'value_avg': 82.91656138333335, 'value_min': 32.305235999999994, 'value_max': 98.269198}, {'clock': 1749686400, 'num': 60, 'value_avg': 83.10747483333336, 'value_min': 31.689283000000003, 'value_max': 98.195413}, {'clock': 1749682800, 'num': 60, 'value_avg': 82.91962181666668, 'value_min': 31.739295, 'value_max': 98.284519}, {'clock': 1749679200, 'num': 60, 'value_avg': 83.0132622, 'value_min': 32.178447000000006, 'value_max': 98.379173}, {'clock': 1749675600, 'num': 60, 'value_avg': 82.92861706666666, 'value_min': 32.321916, 'value_max': 98.113839}, {'clock': 1749672000, 'num': 60, 'value_avg': 83.12122183333331, 'value_min': 31.95326, 'value_max': 98.231464}, {'clock': 1749668400, 'num': 60, 'value_avg': 83.36253551666667, 'value_min': 32.073809999999995, 'value_max': 98.370296}, {'clock': 1749664800, 'num': 60, 'value_avg': 83.5346012333333, 'value_min': 32.841654000000005, 'value_max': 98.193353}, {'clock': 1749661200, 'num': 60, 'value_avg': 83.41092471666668, 'value_min': 32.581106000000005, 'value_max': 98.240776}, {'clock': 1749657600, 'num': 60, 'value_avg': 82.01317551666669, 'value_min': 32.938070999999994, 'value_max': 98.469088}, {'clock': 1749654000, 'num': 60, 'value_avg': 80.68142524999996, 'value_min': 12.966469000000004, 'value_max': 98.722421}, {'clock': 1749650400, 'num': 60, 'value_avg': 83.41137780000001, 'value_min': 32.898995, 'value_max': 98.771263}]

# %% [markdown]
# This is the valid statistical_measure ['min', 'max', 'mean', 'median', 'stdev', 'sum', 'count', 'range', 'mad', 'last', 'avg']

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_metric_data(
        hostname=hostname,
        metric_name=metric_name,
        time_from=time_from,
        time_to=time_to
    )
    print(result)
# Out:
# {'status': 'success', 'data': [{'clock': 1749733284, 'value': 98.61082}, {'clock': 1749733224, 'value': 98.538797}, {'clock': 1749733164, 'value': 98.442943}, {'clock': 1749733104, 'value': 94.625551}, {'clock': 1749733044, 'value': 34.381296000000006}, {'clock': 1749732984, 'value': 65.04236399999999}, {'clock': 1749732924, 'value': 87.424772}, {'clock': 1749732864, 'value': 87.305394}, {'clock': 1749732804, 'value': 75.254266}, {'clock': 1749732744, 'value': 95.366017}, {'clock': 1749732684, 'value': 98.223958}, {'clock': 1749732624, 'value': 98.334452}, {'clock': 1749732564, 'value': 98.462831}, {'clock': 1749732504, 'value': 94.542482}, {'clock': 1749732444, 'value': 35.16354200000001}, {'clock': 1749732384, 'value': 66.160192}, {'clock': 1749732324, 'value': 87.156698}, {'clock': 1749732264, 'value': 87.350435}, {'clock': 1749732204, 'value': 69.42739399999999}, {'clock': 1749732144, 'value': 94.404772}, {'clock': 1749732084, 'value': 98.611169}, {'clock': 1749732024, 'value': 98.409434}, {'clock': 1749731964, 'value': 98.20778}, {'clock': 1749731904, 'value': 94.304541}, {'clock': 1749731844, 'value': 35.57284}, {'clock': 1749731784, 'value': 58.655384}, {'clock': 1749731724, 'value': 87.279226}, {'clock': 1749731664, 'value': 88.339282}, {'clock': 1749731604, 'value': 73.83689100000001}, {'clock': 1749731544, 'value': 94.437919}, {'clock': 1749731484, 'value': 98.204171}, {'clock': 1749731424, 'value': 98.24245}, {'clock': 1749731364, 'value': 98.366355}, {'clock': 1749731304, 'value': 94.813261}, {'clock': 1749731244, 'value': 35.192898}, {'clock': 1749731184, 'value': 57.545424}, {'clock': 1749731124, 'value': 87.423841}, {'clock': 1749731064, 'value': 87.828423}, {'clock': 1749731004, 'value': 67.643843}, {'clock': 1749730944, 'value': 94.999371}, {'clock': 1749730884, 'value': 98.137193}, {'clock': 1749730824, 'value': 98.223191}, {'clock': 1749730764, 'value': 98.231127}, {'clock': 1749730704, 'value': 94.427206}, {'clock': 1749730644, 'value': 34.421476999999996}, {'clock': 1749730584, 'value': 63.284963}, {'clock': 1749730524, 'value': 87.589248}, {'clock': 1749730464, 'value': 87.333417}, {'clock': 1749730404, 'value': 68.272181}, {'clock': 1749730344, 'value': 93.985215}, {'clock': 1749730284, 'value': 97.46777}, {'clock': 1749730224, 'value': 98.362578}, {'clock': 1749730164, 'value': 97.914131}, {'clock': 1749730104, 'value': 94.651533}, {'clock': 1749730044, 'value': 35.642815}, {'clock': 1749729984, 'value': 55.166183}, {'clock': 1749729924, 'value': 87.26013}, {'clock': 1749729864, 'value': 88.783238}, {'clock': 1749729804, 'value': 65.619216}, {'clock': 1749729744, 'value': 93.526542}, {'clock': 1749729684, 'value': 97.232604}, {'clock': 1749729624, 'value': 98.222371}, {'clock': 1749729564, 'value': 98.061267}, {'clock': 1749729504, 'value': 94.63807}, {'clock': 1749729444, 'value': 33.528052}, {'clock': 1749729384, 'value': 61.458027}, {'clock': 1749729324, 'value': 87.888721}, {'clock': 1749729264, 'value': 88.281842}, {'clock': 1749729204, 'value': 83.321415}, {'clock': 1749729144, 'value': 95.567227}, {'clock': 1749729084, 'value': 98.25311}, {'clock': 1749729024, 'value': 98.031314}, {'clock': 1749728964, 'value': 98.572868}, {'clock': 1749728904, 'value': 94.263878}, {'clock': 1749728844, 'value': 34.500147}, {'clock': 1749728784, 'value': 82.088613}, {'clock': 1749728724, 'value': 87.047635}, {'clock': 1749728664, 'value': 88.012459}, {'clock': 1749728604, 'value': 68.943028}, {'clock': 1749728544, 'value': 94.014366}, {'clock': 1749728484, 'value': 97.88697}, {'clock': 1749728424, 'value': 98.265508}, {'clock': 1749728364, 'value': 97.935722}, {'clock': 1749728304, 'value': 93.88422800000001}, {'clock': 1749728244, 'value': 34.770934999999994}, {'clock': 1749728184, 'value': 61.123728}, {'clock': 1749728124, 'value': 86.663858}, {'clock': 1749728064, 'value': 88.19106}, {'clock': 1749728004, 'value': 68.562182}, {'clock': 1749727944, 'value': 94.493143}, {'clock': 1749727884, 'value': 98.152647}, ...

# %% [markdown]
# ## Get Alers

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_all_alerts()
    print(result)
# Out:
# [{'host': 'Zabbix server', 'trigger_name': '{HOST.NAME} has been restarted', 'event_name': 'Zabbix server has been restarted (uptime < 10m)', 'eventid': 7, 'acknowledged': 0, 'start_time': 1722422250, 'end_time': 1722422280, 'duration': 30, 'recovery_eventid': 27}, {'host': 'Zabbix server', 'trigger_name': 'Utilization of http poller processes is high', 'event_name': 'Utilization of http poller processes over 75%', 'eventid': 388, 'acknowledged': 0, 'start_time': 1722438999, 'end_time': 1722444400, 'duration': 5401, 'recovery_eventid': 520}, {'host': 'Zabbix server', 'trigger_name': 'Utilization of poller processes is high', 'event_name': 'Utilization of poller processes over 75%', 'eventid': 498, 'acknowledged': 0, 'start_time': 1722439964, 'end_time': 1722444464, 'duration': 4500, 'recovery_eventid': 523}, {'host': 'Zabbix server', 'trigger_name': 'Number of installed packages has been changed', 'event_name': 'Number of installed packages has been changed', 'eventid': 499, 'acknowledged': 0, 'start_time': 1722440635, 'end_time': 1722444235, 'duration': 3600, 'recovery_eventid': 519}, {'host': 'Zabbix server', 'trigger_name': 'Number of installed packages has been changed', 'event_name': 'Number of installed packages has been changed', 'eventid': 524, 'acknowledged': 0, 'start_time': 1722516235, 'end_time': 1722559435, 'duration': 43200, 'recovery_eventid': 531}, {'host': 'Zabbix server', 'trigger_name': 'Load average is too high', 'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)', 'eventid': 1453, 'acknowledged': 0, 'start_time': 1722864497, 'end_time': 1722864909, 'duration': 412, 'recovery_eventid': 1824}, {'host': 'Zabbix server', 'trigger_name': '/etc/passwd has been changed', 'event_name': '/etc/passwd has been changed', 'eventid': 1827, 'acknowledged': 0, 'start_time': 1722940142, 'end_time': 1722943742, 'duration': 3600, 'recovery_eventid': 1831}, {'host': 'Zabbix server', 'trigger_name': 'Number of installed packages has been changed', 'event_name': 'Number of installed packages has been changed', 'eventid': 1830, 'acknowledged': 0, 'start_time': 1722941035, 'end_time': 1722984235, 'duration': 43200, 'recovery_eventid': 2443}, {'host': 'Zabbix server', 'trigger_name': 'Load average is too high', 'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)', 'eventid': 2023, 'acknowledged': 0, 'start_time': 1722950898, 'end_time': 1722951309, 'duration': 411, 'recovery_eventid': 2440}, {'host': 'Zabbix server', 'trigger_name': 'Load average is too high', 'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)', 'eventid': 2660, 'acknowledged': 0, 'start_time': 1723037297, 'end_time': 1723037709, 'duration': 412, 'recovery_eventid': 2778}, {'host': 'Zabbix server', 'trigger_name': 'Load average is too high', 'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)', 'eventid': 3057, 'acknowledged': 0, 'start_time': 1723123697, 'end_time': 1723124109, 'duration': 412, 'recovery_eventid': 3566}, {'host': 'Zabbix server', 'trigger_name': 'Load average is too high', 'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)', 'eventid': 3887, 'acknowledged': 0, 'start_time': 1723210097, 'end_time': 1723210509, 'duration': 412, 'recovery_eventid': 4242}, {'host': 'Zabbix server', 'trigger_name': 'Load average is too high', 'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)', 'eventid': 4649, 'acknowledged': 0, 'start_time': 1723296489, 'end_time': 1723296969, 'duration': 480, 'recovery_eventid': 5044}, {'host': 'Zabbix server', 'trigger_name': 'Load average is too high', 'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)', 'eventid': 5260, 'acknowledged': 0, 'start_time': 1723382897, 'end_time': 1723383309, 'duration': 412, 'recovery_eventid': 5654}, {'host': 'Zabbix server', 'trigger_name': 'Load average is too high', 'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)', 'eventid': 14313, 'ack ...

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_alerts(
        hostname=hostname,
        time_from=time_from,
        time_to=time_to
    )
result
# Out:
#                host              trigger_name  \
# 5516  Zabbix server  Load average is too high
# 5515  Zabbix server             test baseline
# 5514  Zabbix server  Load average is too high
# 5512  Zabbix server  Load average is too high
# 5511  Zabbix server  Load average is too high
# 5510  Zabbix server  Load average is too high
# 5508  Zabbix server             test baseline
# 5506  Zabbix server             test baseline
#
#                                              event_name  eventid  \
# 5516  Load average is too high (per CPU load over 1....  2388805
# 5515                                      test baseline  2388524
# 5514  Load average is too high (per CPU load over 1....  2387928
# 5512  Load average is too high (per CPU load over 1....  2383770
# 5511  Load average is too high (per CPU load over 1....  2381361
# 5510  Load average is too high (per CPU load over 1....  2379717
# 5508                                      test baseline  2378619
# 5506                                      test baseline  2377027
#
#       acknowledged  start_time    end_time  duration  recovery_eventid
# 5516             0  1749731597  1749731769       172         2388830.0
# 5515             0  1749729624  1749733311      3687               NaN
# 5514             0  1749725529  1749725589        60         2387937.0
# 5512             0  1749696797  1749696969       172         2383795.0
# 5511             0  1749679997  1749680109       112         2381378.0
# 5510             0  1749668589  1749668649        60         2379726.0
# 5508             0  1749661224  1749726024     64800         2388001.0
# 5506             0  1749650424  1749657624      7200         2378088.0

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_common_issues(
    )
result
# Out:
# {'status': 'success',
#  'data': [{'event_name': 'High CPU utilization (over 90% for 5m)',
#    'total_count': 2724,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2724},
#   {'event_name': 'High ICMP ping loss',
#    'total_count': 1169,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1169},
#   {'event_name': 'High Bounce Rate Trigger',
#    'total_count': 232,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 232},
#   {'event_name': 'Load average is too high (per CPU load over 1.5 for 5m)',
#    'total_count': 211,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 211},
#   {'event_name': 'test baseline',
#    'total_count': 173,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 173},
#   {'event_name': 'Anomaly-25',
#    'total_count': 120,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 120},
#   {'event_name': 'Anomaly',
#    'total_count': 77,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 77},
#   {'event_name': 'Unavailable by ICMP ping',
#    'total_count': 59,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 59},
#   {'event_name': 'Low Average Time on Site Trigger',
#    'total_count': 46,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 46},
#   {'event_name': 'GitHub: API request limit utilization is very high (usage is > 90)',
#    'total_count': 39,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 39},
#   {'event_name': 'Service is down',
#    'total_count': 37,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 37},
#   {'event_name': 'No SNMP data collection',
#    'total_count': 33,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 33},
#   {'event_name': 'Interface Et0/0(): High error rate (>2 for 5m)',
#    'total_count': 26,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 26},
#   {'event_name': 'Anomaly-2',
#    'total_count': 23,
#    'acknowledged_count': 1,
#    'unacknowledged_count': 22},
#   {'event_name': 'Number of installed packages has been changed',
#    'total_count': 22,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 22},
#   {'event_name': 'Proxy [Zabbix proxy]: Zabbix proxy last seen more than 600 seconds ago',
#    'total_count': 20,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 20},
#   {'event_name': 'Anomly Detect',
#    'total_count': 19,
#    'acknowledged_count': 1,
#    'unacknowledged_count': 18},
#   {'event_name': 'DNS Query Time is High for https://nw9.digital (More than 10 milliseconds)',
#    'total_count': 18,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 18},
#   {'event_name': 'Proxy [Zabbix proxy1]: Zabbix proxy last seen more than 600 seconds ago',
#    'total_count': 17,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 17},
#   {'event_name': 'Zabbix agent is not available (for 3m)',
#    'total_count': 16,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 16},
#   {'event_name': 'parkar.in is not available',
#    'total_count': 15,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 15},
#   {'event_name': 'GitHub: There are errors in requests to API',
#    'total_count': 13,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 13},
#   {'event_name': 'jenkin has been restarted (uptime < 10m)',
#    'total_count': 12,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 12},
#   {'event_name': 'Liveness check was failed',
#    'total_count': 11,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 11},
#   {'event_name': 'Interface Et0/1(): High error rate (>2 for 5m)',
#    'total_count': 9,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 9},
#   {'event_name': 'Step  "create-jira-ticket"   "Update README.md" "Create Jira Ticket on Commit" is Failed',
#    'total_count': 9,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 9},
#   {'event_name': 'Switch1 has been restarted (uptime < 10m)',
#    'total_count': 8,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 8},
#   {'event_name': 'Page Load Time is High for https://nw9.digital (More than 50 Seconds)',
#    'total_count': 8,
#    'acknowledged_count': 3,
#    'unacknowledged_count': 5},
#   {'event_name': 'Gitlab instance is not able to accept traffic',
#    'total_count': 7,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 7},
#   {'event_name': 'Minimum Job Duration Too Low (Indicating Possible Job Errors) 5s',
#    'total_count': 6,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 6},
#   {'event_name': 'Router1 has been restarted (uptime < 10m)',
#    'total_count': 6,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 6},
#   {'event_name': 'Interface Et0/0(): In half-duplex mode',
#    'total_count': 6,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 6},
#   {'event_name': 'Switch2 has been restarted (uptime < 10m)',
#    'total_count': 6,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 6},
#   {'event_name': 'Failed to get alarms data',
#    'total_count': 6,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 6},
#   {'event_name': 'GitHub: API request limit utilization is high (usage is > 80)',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'Zabbix server has been restarted (uptime < 10m)',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': '/etc/passwd has been changed',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'More than 100 items having missing data for more than 10 minutes',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'High CPU utilization (over 50% for 5m)',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'High Server Response Time Trigger',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'Job Success Rate Too Low 50%',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'Very Short Job Execution (Potential Errors)  (Run)  30s',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'Firewall1 SNMP has been restarted (uptime < 10m)',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'Success Rate Too Low (Run)  40',
#    'total_count': 5,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 5},
#   {'event_name': 'High Network Latency Trigger',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'Step {ITEM.VALUE1.jsonpath("$.[?(@.conclusion == \'failure\')].name")}  "create-jira-ticket"   "Update README.md" "Create Jira Ticket on Commit" is Failed',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'Step --- create-jira-ticket --- Update README.md --- Create Jira Ticket on Commit is Failed',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'Time to First Byte Time is High for https://nw9.digital (More than 20 Seconds)',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'SSL Handshake Time is High for https://nw9.digital (More than 18 Seconds)',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'Interface Et0/2(): Link down',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'High Page Load Time Trigger',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'No Runs Running (Possible System Issue)  (Run) 0',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'GitHub: The total number of PRs has increased',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'cpu anomaly',
#    'total_count': 4,
#    'acknowledged_count': 1,
#    'unacknowledged_count': 3},
#   {'event_name': 'Download Speed is Low for https://nw9.digital (Less than 12 Kbps)',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'No Jobs Running (Potential System Failure) 0',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'DNS Query Time is High for https://nw9.digital (More than 20 milliseconds)',
#    'total_count': 4,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 4},
#   {'event_name': 'HTTP Probe Duration is High for https://nw9.digital (More than 14 milliseconds)',
#    'total_count': 3,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 3},
#   {'event_name': 'Failed to get metrics data',
#    'total_count': 3,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 3},
#   {'event_name': 'High ICMP ping response time',
#    'total_count': 3,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 3},
#   {'event_name': 'Zabbix agent is not available (or nodata for 30m)',
#    'total_count': 3,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 3},
#   {'event_name': 'test',
#    'total_count': 3,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 3},
#   {'event_name': 'Interface Et0/2(): In half-duplex mode',
#    'total_count': 3,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 3},
#   {'event_name': 'Active checks are not available',
#    'total_count': 3,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 3},
#   {'event_name': 'Interface Et0/1(): In half-duplex mode',
#    'total_count': 3,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 3},
#   {'event_name': 'sda: Disk read/write request responses are too high (read > 20 ms for 15m or write > 20 ms for 15m)',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Anomaly2',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Interface Et0/3(): Link down',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'FS [/]: Space is low (used > 80%, total 48.9GB)',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'High Reattempt Rate (Indicating Job Failures and Retrying Issues)  (Run)  5',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Interface Et0/1(): High bandwidth usage (>90%)',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Page Load Time is High for https://nw9.digital (More than 16 Seconds)',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'High Job Failure Rate 50%',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Operating system description has changed',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'High Failure Rate Detected (Run) 50%',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Tablespace USERS Usage Exceeded 1',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Tablespace USERS Usage Exceeded 80%',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Too Many Consecutive Failures (Run) 15',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Too Many Jobs Failed in a Row 10',
#    'total_count': 2,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 2},
#   {'event_name': 'Readyz [poststarthook/priority-and-fairness-filter] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-apiextensions-informers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/priority-and-fairness-config-consumer] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/priority-and-fairness-config-producer] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-cluster-authentication-info-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-apiextensions-controllers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/scheduling/bootstrap-system-priority-classes] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/rbac/bootstrap-roles] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [ping] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/kube-apiserver-autoregistration] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/aggregator-reload-proxy-client-cert] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [autoregister-completion] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [etcd-readiness] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [etcd] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [informer-sync] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [log] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-kube-apiserver-admission-initializer] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/apiservice-discovery-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/generic-apiserver-start-informers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/apiservice-openapi-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/apiservice-openapiv3-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/apiservice-registration-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/apiservice-status-available-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/bootstrap-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/crd-informer-synced] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-kube-aggregator-informers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': '"spice-agent" (Spice Agent) is not running (startup type automatic)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-kube-apiserver-identity-lease-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-kube-apiserver-identity-lease-garbage-collector] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of escalator processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of history syncer processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of housekeeper processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of http poller processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of poller processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of service manager processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of task manager processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of timer processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of trigger housekeeper processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Version has changed (new version: 7.0.11)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Website Down (Status Not 200) : 200',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Website loading slowly : 148.55',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Website loading slowly : 781.27 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'asg-ip-13.203.155.142 has been restarted (uptime < 10m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'asg-ip-13.232.218.1 has been restarted (uptime < 10m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'ip-172-31-54-55.ec2.internal has been restarted (uptime < 10m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'ip-172-31-57-240.ec2.internal has been restarted (uptime < 10m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of connector worker processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of configuration syncer processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of availability manager processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'SSL certificate is expiring soon : 14 Days Left',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-legacy-token-tracking-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-service-ip-repair-controllers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/start-system-namespaces-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [poststarthook/storage-object-count-tracker-hook] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Readyz [shutdown] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Router2 has been restarted (uptime < 10m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'RunsOverall Metrics',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'SSL certificate is expiring soon : 57 Days Left',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Utilization of alert syncer processes over 75%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Step   {ITEM.VALUE1.jsonpath("$.[?(@.conclusion == \'success\')].name")} --- create-jira-ticket --- Update README.md --- Create Jira Ticket on Commit is Failed',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Step  "create-jira-ticket"   "TEst" "Create Jira Ticket on Commit" is Failed',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Step --- create-jira-ticket --- Testing --- Create Jira Ticket on Commit is Failed',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Step {ITEM.VALUE1.jsonpath("$.[?(@.conclusion == \'failure\')].name")}  "create-jira-ticket"   "TEst" "Create Jira Ticket on Commit" is Failed',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Proxy [zabbix-proxy-sqlite3]: Zabbix proxy is outdated',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'System name has changed (new name: Router2)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Tablespace UNDO_T1 Usage Exceeded 80%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Proxy [zabbix-proxy-sqlite3]: Zabbix proxy last seen more than 600 seconds ago',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-apiextensions-informers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Proxy [test1]: Zabbix proxy never seen',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :311.81 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :12.9',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :2.05 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :2.3 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :262.15 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :290.15 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :3.17 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :3.2 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :3.52 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :3.95 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :317.69 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Proxy [test1]: Zabbix proxy last seen more than 600 seconds ago',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :4.22 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :4.82 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :4.94 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :8.34 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High Job Failure Rate (new)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High SSL handshake time : 264.76 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High SSL handshake time : 52.84',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High TCP connect time : 16.43',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High TCP connect time : 248.9 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :1.9 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :1.62 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :1.26 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High DNS resolution time :1.16 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Component [controller-manager] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Component [etcd-0] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Component [scheduler] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Connection to mongos proxy is unavailable',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Download Speed is Low for App.pssadvantage.com (Less than 768 Kbps)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Download Speed is Low for app.psiaccess.com (Less than 768 Kbps)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Download Speed is Low for https://www.parkar.in/ (Less than 768 Kbps)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Download Speed is Low for {$TARGET_URL} (Less than 768 Kbps)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'FS [/]: Space is critically low (used > 90%, total 48.9GB)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Failed to fetch info data (or no data for 10m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Failed to fetch info data (or no data for 30m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Failed to get events data',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Failed to get instance data',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Firewall2 SNMP has been restarted (uptime < 10m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'GitHub Workflow Inactive Alert',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'GitHub: Workflow [Check Commit Message for "GitHub"]: The workflow has failed',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'GitHub: Workflow [Link Commit to Jira Ticket]: The workflow has failed',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High CPU utilization (over 5% for 5m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High CPU utilization (over 80% for 5m)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High TCP connect time : 255.65 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High TCP connect time : 259.47 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High TTFB (Slow backend response) : 1.01 Kmilliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/crd-informer-synced] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/kube-apiserver-autoregistration] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/priority-and-fairness-config-consumer] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/priority-and-fairness-config-producer] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/priority-and-fairness-filter] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/rbac/bootstrap-roles] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/scheduling/bootstrap-system-priority-classes] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-apiextensions-controllers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-cluster-authentication-info-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-kube-aggregator-informers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-kube-apiserver-admission-initializer] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-kube-apiserver-identity-lease-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-kube-apiserver-identity-lease-garbage-collector] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-legacy-token-tracking-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-service-ip-repair-controllers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/start-system-namespaces-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/storage-object-count-tracker-hook] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Maximum Job Duration Exceeded 900s',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Proxy [ZBX_SERVER_HOST]: Zabbix proxy never seen',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Proxy [Zabbix proxy]: Zabbix proxy is outdated',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/generic-apiserver-start-informers] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/bootstrap-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High TTFB (Slow backend response) : 1021.74',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/apiservice-status-available-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High TTFB (Slow backend response) : 143.38',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High TTFB (Slow backend response) : 781.06 milliseconds',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'High swap space usage (less than 50% free)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Interface Et0/0(): High bandwidth usage (>90%)',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Interface Et0/0(): Link down',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Interface Et0/3(): In half-duplex mode',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Interface port2(): Link down',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Job Failure Rate Exceeds 19%',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Job [demo]: Job is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Large page size detected : 105357',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [autoregister-completion] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [etcd] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [log] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [ping] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/aggregator-reload-proxy-client-cert] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/apiservice-discovery-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/apiservice-openapi-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/apiservice-openapiv3-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'Livez [poststarthook/apiservice-registration-controller] is unhealthy',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1},
#   {'event_name': 'test-2',
#    'total_count': 1,
#    'acknowledged_count': 0,
#    'unacknowledged_count': 1}]}

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_host_by_metric(
        metric_name=metric_name,
        time_from=time_from,
        time_to=time_to
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 with zb.ZabbixDB(**db_config) as zbx:
# ----> 2     result = zbx.get_host_by_metric(
#       3         metric_name=metric_name,
#       4         time_from=time_from,
#       5         time_to=time_to
#       6     )
#
# File ~/zabbix_db_lib/zabbix_db.py:614, in ZabbixDB.get_host_by_metric(self, metric_name, statistical_measure, time_from, time_to, limit)
#     612 rows = []
#     613 for host in hostnames:
# --> 614     metric_data = self.get_metric_data(
#     615         hostname=host,
#     616         metric_name=metric_name,
#     617         time_from=time_from,
#     618         time_to=time_to,
#     619         statistical_measure=statistical_measure
#     620     )
#     622     if metric_data:
#     623         data_points = metric_data.get("data")
#
# File ~/zabbix_db_lib/zabbix_db.py:503, in ZabbixDB.get_metric_data(self, hostname, metric_name, time_from, time_to, statistical_measure)
#     495         return (history_data or []) + (trend_data or [])
#     497     fetch_func = {
#     498         "get_history": fetch_history_with_stats if statistical_measure else lambda: fetch_history() or [],
#     499         "get_trends": fetch_trends_with_stats if statistical_measure else lambda: fetch_trends() or [],
#     500         "get_trends_and_history": fetch_both_with_stats if statistical_measure else fetch_both_raw
#     501     }
# --> 503     data = fetch_func[function_name]()
#     505     return self._success_response(
#     506         data=data,
#     507         hostname=hostname,
#    (...)
#     510         statistical_measure=statistical_measure
#     511     )
#     514 except (MySQLError, PostgresError) as e:
#
# File ~/zabbix_db_lib/zabbix_db.py:477, in ZabbixDB.get_metric_data.<locals>.fetch_history_with_stats()
#     476 def fetch_history_with_stats():
# --> 477     data = fetch_history()
#     478     return self.compute_statistic(data, statistical_measure) if data else []
#
# File ~/zabbix_db_lib/zabbix_db.py:470, in ZabbixDB.get_metric_data.<locals>.fetch_history()
#     469 def fetch_history():
# --> 470     return self.get_history_data(itemid, time_from, time_to, history_table, statistical_measure)
#
# File ~/zabbix_db_lib/zabbix_db.py:396, in ZabbixDB.get_history_data(self, itemid, time_from, time_to, history_table_name, statistical_measure)
#     393             return RuntimeError(f"Invalid statistical measure: {statistical_measure}")
#     395         # Compute the requested statistic
# --> 396         return self.compute_statistic(result, statistical_measure)
#     397     return result
#     399 except (MySQLError, PostgresError) as e:
#
# File ~/zabbix_db_lib/zabbix_db.py:96, in ZabbixDB.compute_statistic(self, data, operation)
#      80 """
#      81 Computes a statistical measure on a list of dicts with 'clock' and 'value'.
#      82
#    (...)
#      93     - For others: Single float/int result
#      94 """
#      95 if not data:
# ---> 96     raise ValueError("Data list is empty.")
#      98 # operation = operation.lower()
#      99 values = [item['value'] for item in data]
#
# ValueError: Data list is empty.

# %%
with zb.ZabbixDB(**db_config) as zbx:
    result = zbx.get_metric_data(
        hostname=hostname,
        metric_name=metric_name,
        time_from=1749032410,
        time_to=1749118810
    )
    print(result)
# Out:
# {'status': 'success', 'data': [{'clock': 1749118764, 'value': 98.223637}, {'clock': 1749118704, 'value': 94.208058}, {'clock': 1749118644, 'value': 36.390408}, {'clock': 1749118584, 'value': 68.02237600000001}, {'clock': 1749118524, 'value': 87.269668}, {'clock': 1749118464, 'value': 86.801582}, {'clock': 1749118404, 'value': 83.14017}, {'clock': 1749118344, 'value': 94.557052}, {'clock': 1749118284, 'value': 98.065383}, {'clock': 1749118224, 'value': 98.442289}, {'clock': 1749118164, 'value': 98.889587}, {'clock': 1749118104, 'value': 95.123687}, {'clock': 1749118044, 'value': 41.248686}, {'clock': 1749117984, 'value': 70.57957}, {'clock': 1749117924, 'value': 86.79547099999999}, {'clock': 1749117864, 'value': 89.437182}, {'clock': 1749117804, 'value': 78.19166799999999}, {'clock': 1749117744, 'value': 94.421592}, {'clock': 1749117684, 'value': 98.280706}, {'clock': 1749117624, 'value': 98.484467}, {'clock': 1749117564, 'value': 98.179612}, {'clock': 1749117504, 'value': 94.69112}, {'clock': 1749117444, 'value': 37.150533}, {'clock': 1749117384, 'value': 62.856783}, {'clock': 1749117324, 'value': 88.870201}, {'clock': 1749117264, 'value': 87.243697}, {'clock': 1749117204, 'value': 69.151261}, {'clock': 1749117144, 'value': 94.965992}, {'clock': 1749117084, 'value': 97.498949}, {'clock': 1749117024, 'value': 97.411438}, {'clock': 1749116964, 'value': 97.850228}, {'clock': 1749116904, 'value': 94.291471}, {'clock': 1749116844, 'value': 35.801899000000006}, {'clock': 1749116784, 'value': 70.716328}, {'clock': 1749116724, 'value': 87.122838}, {'clock': 1749116664, 'value': 88.238255}, {'clock': 1749116604, 'value': 74.475068}, {'clock': 1749116544, 'value': 94.296162}, {'clock': 1749116484, 'value': 97.692856}, {'clock': 1749116424, 'value': 98.171218}, {'clock': 1749116364, 'value': 98.479963}, {'clock': 1749116304, 'value': 94.783192}, {'clock': 1749116244, 'value': 34.31903}, {'clock': 1749116184, 'value': 56.764595}, {'clock': 1749116124, 'value': 87.740902}, {'clock': 1749116064, 'value': 88.73269}, {'clock': 1749116004, 'value': 69.248895}, {'clock': 1749115944, 'value': 94.347863}, {'clock': 1749115884, 'value': 98.188223}, {'clock': 1749115824, 'value': 97.985394}, {'clock': 1749115764, 'value': 98.077487}, {'clock': 1749115704, 'value': 94.80966}, {'clock': 1749115644, 'value': 32.055266}, {'clock': 1749115584, 'value': 51.065708}, {'clock': 1749115524, 'value': 87.42278400000001}, {'clock': 1749115464, 'value': 88.233319}, {'clock': 1749115404, 'value': 77.227181}, {'clock': 1749115344, 'value': 95.045764}, {'clock': 1749115284, 'value': 98.20005}, {'clock': 1749115224, 'value': 98.414696}, {'clock': 1749115164, 'value': 98.463664}, {'clock': 1749115104, 'value': 94.531807}, {'clock': 1749115044, 'value': 33.666611}, {'clock': 1749114984, 'value': 59.53694}, {'clock': 1749114924, 'value': 87.071251}, {'clock': 1749114864, 'value': 87.520973}, {'clock': 1749114804, 'value': 72.022382}, {'clock': 1749114744, 'value': 94.057782}, {'clock': 1749114684, 'value': 96.876184}, {'clock': 1749114624, 'value': 97.140097}, {'clock': 1749114564, 'value': 97.938794}, {'clock': 1749114504, 'value': 94.166247}, {'clock': 1749114444, 'value': 34.196174}, {'clock': 1749114384, 'value': 58.941567}, {'clock': 1749114324, 'value': 86.980131}, {'clock': 1749114264, 'value': 87.953878}, {'clock': 1749114204, 'value': 65.72679099999999}, {'clock': 1749114144, 'value': 94.113448}, {'clock': 1749114084, 'value': 98.091843}, {'clock': 1749114024, 'value': 98.091043}, {'clock': 1749113964, 'value': 97.89923}, {'clock': 1749113904, 'value': 93.849897}, {'clock': 1749113844, 'value': 32.079116}, {'clock': 1749113784, 'value': 59.772144}, {'clock': 1749113724, 'value': 87.13342}, {'clock': 1749113664, 'value': 87.045044}, {'clock': 1749113604, 'value': 73.175749}, {'clock': 1749113544, 'value': 95.08121}, {'clock': 1749113484, 'value': 97.761915}, {'clock': 1749113424, 'value': 97.635844}, {'clock': 1749113364, 'value': 97.985846}, {'clock': 17491133 ...

# %%
with zb.ZabbixDB(**db_config) as zbx:
    item_details = zbx.get_item_detail(metric_name)

    if not item_details:
        print(pd.DataFrame(columns=['hostname', 'unit', 'clock', 'value']))
    if not isinstance(item_details, list):
        item_details = [item_details]

    hostnames = list({item['hostname'] for item in item_details})

    rows = []
    for host in hostnames:
        metric_data = self.get_metric_data(
            hostname=host,
            metric_name=metric_name,
            time_from=time_from,
            time_to=time_to,
            statistical_measure=statistical_measure
        )
